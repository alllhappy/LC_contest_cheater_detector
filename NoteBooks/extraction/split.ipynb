# %% [markdown]
# This Notebook was used to perform the basic null value,handling duplicaates and  test/train split for 3 contests - 494,495,496.

# %% [markdown]
# Final Script to achieve same output is   /dataset_extraction/split/split.py

# %% [markdown]
# # NOTEBOOK START

# %%
import sys
from pathlib import Path
ROOT_DIR = Path().resolve().parent.parent
print(ROOT_DIR)
# Out:
# C:\Users\karan\Desktop\lc_contest_cheater_detector

# %% [markdown]
# opening all contest files as data seprate data frames

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
path_494= ROOT_DIR / "dataset"/ 'contest_494' /'weekly_contest494.csv'
path_495= ROOT_DIR / "dataset"/ 'contest_495' /'weekly_contest495.csv'
path_496= ROOT_DIR / "dataset"/ 'contest_496' /'weekly_contest496.csv'

df_494=pd.read_csv(path_494)
df_495=pd.read_csv(path_495)
df_496=pd.read_csv(path_496)

# df_494[df_494['Rank']==1532]

# %%
print(df_496.shape)
print(df_495.shape)
print(df_494.shape)
# Out:
# (9408, 31)
# (9377, 31)
# (9138, 31)

# %% [markdown]
# Creating copies of original dataframes

# %%
df1=df_494.copy()
df2=df_495.copy() # df2=df results in same dataframe reference no copy is made
df3=df_496.copy()

# %% [markdown]
# Examining the datatypes for the orginal CSV file

# %%
df_494.dtypes
# Out:
# Rank                 int64
# User_slug              str
# Score                int64
# CurrConSolved        int64
# FinishTimeStamp      int64
# Q1TimeStamp        float64
# Q2TimeStamp        float64
# Q3TimeStamp        float64
# Q4TimeStamp        float64
# Q1FailCnt          float64
# Q2FailCnt          float64
# Q3FailCnt          float64
# Q4FailCnt          float64
# UserName               str
# CountryName            str
# RankingP             int64
# PostViewCnt          int64
# Reputation           int64
# TotalQsAcc           int64
# TotalQsSub           int64
# EasyQsAcc            int64
# EasyQsSub            int64
# MedQsAcc             int64
# MedQsSub             int64
# HardQsAcc            int64
# HardQsSub            int64
# ContestCnt           int64
# CurrRating         float64
# GlobalRank           int64
# topPercentage      float64
# ContestHistory         str
# dtype: object

# %% [markdown]
# convert into suitable data types and handling null values

# %%
for i in range(1,5):
    df1[f'Q{i}FailCnt'] = df1[f'Q{i}FailCnt'].fillna(0).astype('int64')
    df1[f'Q{i}TimeStamp'] = df1[f'Q{i}TimeStamp'].fillna(0).astype('int64')
df1['CurrRating'] = df1['CurrRating'].astype('int64')
df1.head()
# Out:
#    Rank       User_slug  Score  CurrConSolved  FinishTimeStamp  Q1TimeStamp  \
# 0     1   sunnynguyenai     18              4       1774147102   1774146894
# 1     3       himank028     18              4       1774147143   1774147143
# 2     4     hfgdnnvnxfg     18              4       1774147151   1774147026
# 3     5  dark_knight_bt     18              4       1774147191   1774146758
# 4     6   ayushkumar980     18              4       1774147203   1774146762
#
#    Q2TimeStamp  Q3TimeStamp  Q4TimeStamp  Q1FailCnt  Q2FailCnt  Q3FailCnt  \
# 0   1774147102   1774146997   1774147053          0          0          0
# 1   1774146765   1774146796   1774147000          0          0          0
# 2   1774147079   1774147151   1774147133          0          0          0
# 3   1774146889   1774147090   1774147191          0          0          0
# 4   1774146874   1774147013   1774147203          0          0          0
#
# ...

# %%
for i in range(1,5):
    df2[f'Q{i}FailCnt'] = df2[f'Q{i}FailCnt'].fillna(0).astype('int64')
    df2[f'Q{i}TimeStamp'] = df2[f'Q{i}TimeStamp'].fillna(0).astype('int64')
df2['CurrRating'] = df2['CurrRating'].astype('int64')
df2.head()
# Out:
#    Rank       User_slug  Score  CurrConSolved  FinishTimeStamp  Q1TimeStamp  \
# 0     1  TechhnicalCode     19              4       1774751718   1774751618
# 1     2   VeritasVelata     19              4       1774751783   1774751460
# 2     3          mann_1     19              4       1774751822   1774751467
# 3     4      w7AOsRUeuu     19              4       1774751879   1774751537
# 4     5       scale5558     19              4       1774751884   1774751621
#
#    Q2TimeStamp  Q3TimeStamp  Q4TimeStamp  Q1FailCnt  Q2FailCnt  Q3FailCnt  \
# 0   1774751654   1774751695   1774751718          0          0          0
# 1   1774751548   1774751686   1774751783          0          0          0
# 2   1774751579   1774751735   1774751822          0          0          0
# 3   1774751606   1774751879   1774751730          0          0          0
# 4   1774751603   1774751759   1774751884          0          0          0
#
# ...

# %%
for i in range(1,5):
    df3[f'Q{i}FailCnt'] = df3[f'Q{i}FailCnt'].fillna(0).astype('int64')
    df3[f'Q{i}TimeStamp'] = df3[f'Q{i}TimeStamp'].fillna(0).astype('int64')
df3['CurrRating'] = df2['CurrRating'].astype('int64')
df3.head()
# Out:
#    Rank      User_slug  Score  CurrConSolved  FinishTimeStamp  Q1TimeStamp  \
# 0     1  VeritasVelata     20              4       1775356616   1775356278
# 1     2  ayushkumar980     20              4       1775356691   1775356407
# 2     3      raunak111     20              4       1775356699   1775356699
# 3     4       Mona0405     20              4       1775356752   1775356539
# 4     5      scale5558     20              4       1775356771   1775356573
#
#    Q2TimeStamp  Q3TimeStamp  Q4TimeStamp  Q1FailCnt  Q2FailCnt  Q3FailCnt  \
# 0   1775356366   1775356478   1775356616          0          0          0
# 1   1775356434   1775356637   1775356691          0          0          0
# 2   1775356402   1775356576   1775356663          0          0          0
# 3   1775356594   1775356648   1775356752          0          0          0
# 4   1775356561   1775356600   1775356771          0          0          0
#
# ...

# %%
df2
# Out:
#       Rank       User_slug  Score  CurrConSolved  FinishTimeStamp  \
# 0        1  TechhnicalCode     19              4       1774751718
# 1        2   VeritasVelata     19              4       1774751783
# 2        3          mann_1     19              4       1774751822
# 3        4      w7AOsRUeuu     19              4       1774751879
# 4        5       scale5558     19              4       1774751884
# ...    ...             ...    ...            ...              ...
# 9372  2471     Nightmare16     13              3       1774754947
# 9373  2472     UmarAhmed30     13              3       1774754947
# 9374  2473      Bharath_77     13              3       1774754948
# 9375  2474    Srishanth_45     13              3       1774754948
# 9376  2475     Siddhesh_17     13              3       1774754949
#
#       Q1TimeStamp  Q2TimeStamp  Q3TimeStamp  Q4TimeStamp  Q1FailCnt  \
# 0      1774751618   1774751654   1774751695   1774751718          0
# ...

# %%
df3
# Out:
#       Rank        User_slug  Score  CurrConSolved  FinishTimeStamp  \
# 0        1    VeritasVelata     20              4       1775356616
# 1        2    ayushkumar980     20              4       1775356691
# 2        3        raunak111     20              4       1775356699
# 3        4         Mona0405     20              4       1775356752
# 4        5        scale5558     20              4       1775356771
# ...    ...              ...    ...            ...              ...
# 9403  2471  invincible_at__     14              3       1775360376
# 9404  2472      ArshTiwari7     14              3       1775360378
# 9405  2473        tester_jz     14              3       1775360380
# 9406  2474           thaowu     14              3       1775360381
# 9407  2475   Arnav_Bhardwaj     14              3       1775360384
#
#       Q1TimeStamp  Q2TimeStamp  Q3TimeStamp  Q4TimeStamp  Q1FailCnt  \
# 0      1775356278   1775356366   1775356478   1775356616          0
# ...

# %% [markdown]
# test train Split
# will label this test data for model evaluation
# Also Make Ensure that training data is used for training purposes
#
# ensure no data leakage. if a person is in testing data set make sure present in other training (possible when the person has participated in 2 or more contest)

# %%
from sklearn.model_selection import train_test_split

# 60 row from each contest should be used
X1_train, X1_test = train_test_split(
    df1,
    test_size=0.0065, #will give 60 rows
    random_state=41
)

X2_train, X2_test = train_test_split(
    df2,
    test_size=0.0063, #will give 60 rows
    random_state=41
)

X3_train, X3_test = train_test_split(
    df3,
    test_size=0.0063, #will give 60 rows
    random_state=41
)

print(X1_test.shape)
print(X2_test.shape)
print(X3_test.shape)
# Out:
# (60, 31)
# (60, 31)
# (60, 31)

# %%
X1_test['contest_id']=1
X2_test['contest_id']=2
X3_test['contest_id']=3
X_test=pd.concat([X1_test,X2_test,X3_test],ignore_index=True) #combine all test dataset into 1
X_test.shape
# Out:
# (180, 32)

# %% [markdown]
# see Rank distribution in testing data

# %%
X_test.head()
# Out:
#    Rank            User_slug  Score  CurrConSolved  FinishTimeStamp  \
# 0  6287  chaitanya_vankhande     12              3       1774150740
# 1  6249       Nishant_Raj_29     12              3       1774150711
# 2  5870               skodag     12              3       1774150470
# 3  8455        radhekrishn04     12              3       1774152957
# 4  6523                 LZNB     12              3       1774150885
#
#    Q1TimeStamp  Q2TimeStamp  Q3TimeStamp  Q4TimeStamp  Q1FailCnt  Q2FailCnt  \
# 0   1774146998   1774147335   1774150440            0          0          0
# 1   1774146893   1774148152   1774150711            0          0          0
# 2   1774146932   1774147761   1774150470            0          0          0
# 3   1774146736   1774147291   1774150857            0          0          2
# 4   1774146742   1774147864   1774149385            0          0          3
#
#    Q3FailCnt  Q4FailCnt             UserName    CountryName  RankingP  \
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
ranges=[]
lb=[]
for i in range(1,10000,1000):
    ranges.append(i-1)

def showDist(X_t):
    X=X_t.copy()
    X['range'] = pd.cut(X['Rank'], ranges)
    X['range'].value_counts().sort_index().plot(kind='bar') #histogram has no gaps b/w them also is more suitable for continuous data distribution
    plt.xlabel('Rank Range')
    plt.ylabel('Count')
    plt.title('Distribution of Rank Ranges in Test Dataset')
    plt.xticks(rotation=80)

# %%
showDist(X_test)
print(f'minium Rank = {X_test["Rank"].min()},maxiumum rank = {X_test["Rank"].max()}')
# Out:
# minium Rank = 12,maxiumum rank = 9932

# %% [markdown]
# saving the testing dataset as csv file and manually review it each row on google sheets to mark them with shivam. manually labelled the 180 people

# %%
import csv
output_path= ROOT_DIR / 'dataset'
X_test.to_csv(output_path/'testing_data.csv',index=False,quoting=csv.QUOTE_ALL) #https://chatgpt.com/s/t_69dc87e3b8b48191a31210fe483a87db
# need to add contest id in testing data also

# %%
labeled_data=pd.read_csv(output_path/'testing_data_labelled.csv') #use when all are labelled and marked to read the file exported from google sheet
labeled_data.head()
# Out:
#    Rank            User_slug  Score  CurrConSolved  FinishTimeStamp  \
# 0  6287  chaitanya_vankhande     12              3       1774150740
# 1  6249       Nishant_Raj_29     12              3       1774150711
# 2  5870               skodag     12              3       1774150470
# 3  8455        radhekrishn04     12              3       1774152957
# 4  6523                 LZNB     12              3       1774150885
#
#    Q1TimeStamp  Q2TimeStamp  Q3TimeStamp  Q4TimeStamp  Q1FailCnt  Q2FailCnt  \
# 0   1774146998   1774147335   1774150440            0          0          0
# 1   1774146893   1774148152   1774150711            0          0          0
# 2   1774146932   1774147761   1774150470            0          0          0
# 3   1774146736   1774147291   1774150857            0          0          2
# 4   1774146742   1774147864   1774149385            0          0          3
#
#    Q3FailCnt  Q4FailCnt             UserName    CountryName  RankingP  \
# ...

# %% [markdown]
# now Training data. contcatenation
# and merge by contest id
# 494 -> 1
# 495 -> 2
# 496 -> 3
#
# after concatenation remove users which are duplicates. that is they have given 2 or more of the contests. As can lead to problems later like
# unable to decide for model . in 1 it act as cheater and in other it act as fair then problem. taking only their last participation
# so 1 extra column will be added

# %%
X1_train['contest_id']=1
X2_train['contest_id']=2
X3_train['contest_id']=3

# %%
X1_train.head()
# Out:
#       Rank           User_slug  Score  CurrConSolved  FinishTimeStamp  \
# 7003  9328         Rishikesh_E      7              2       1774147093
# 5304  7650              ProD24     12              3       1774151835
# 2642  5011        vanshika1594     12              3       1774149969
# 3259  5652    yourstherapist01     12              3       1774150336
# 8589  1935  Dhyanam_Janardhana     12              3       1774147947
#
#       Q1TimeStamp  Q2TimeStamp  Q3TimeStamp  Q4TimeStamp  Q1FailCnt  \
# 7003   1774146815   1774147093            0            0          0
# 5304   1774150834   1774151004   1774151835            0          0
# 2642   1774148045   1774148654   1774149969            0          0
# 3259   1774148286   1774149689   1774150336            0          0
# 8589   1774146715   1774147009   1774147947            0          0
#
#       Q2FailCnt  Q3FailCnt  Q4FailCnt          UserName CountryName  RankingP  \
# ...

# %%
X_train=pd.concat([X1_train,X2_train,X3_train],ignore_index=True) #combine all test dataset into 1

X_train.shape
# Out:
# (27743, 32)

# %%
X_train_copy=X_train.copy()

# %%
# X_train_copy=X_train.drop_duplicates(subset='User_slug',keep='first') #taking only last instance overlapping participants of contest
X_train_copy.shape
# Out:
# (27743, 32)

# %%
print(X_train_copy.duplicated(subset='User_slug').sum()) #these many duplicates see
# Out:
# 8560

# %% [markdown]
# #seeing the duplicates

# %%
dups = X_train_copy[X_train_copy.duplicated(subset='User_slug', keep=False)].sort_values(by='User_slug')

# %% [markdown]
# examining both users. or cheater behaviour in them

# %%
dups
# Out:
#        Rank  User_slug  Score  CurrConSolved  FinishTimeStamp  Q1TimeStamp  \
# 27446  4415    0007RAM     11              2       1775362458            0
# 6992   1516    0007RAM     14              3       1774155087   1774149664
# 14157  4617    0007RAM     13              3       1774758032   1774754295
# 13753  8721  01aashish      7              2       1774753195   1774752182
# 25328  6904  01aashish      9              2       1775358161   1775358161
# ...     ...        ...    ...            ...              ...          ...
# 25993  3407      zvxvz     14              3       1775361555   1775357450
# 10159  5917      zvxvz      7              2       1774752260   1774751802
# 3080   8288      zvxvz     12              3       1774152544   1774147463
# 1582   3158      zzz19     12              3       1774148913   1774147031
# 12674  5428      zzz19      7              2       1774752031   1774751560
#
# ...

# %%
X_train_clean=X_train.drop_duplicates(subset='User_slug', keep='last') #new dataframe will be creater by drop_duplicates unlike df2= df which creates new reference only not object
X_train_clean.shape
# Out:
# (19183, 32)

# %% [markdown]
# Saving this for training and hence test train split is successfully implemented along with cleans.

# %%
output_path=ROOT_DIR/'dataset'
df_test=pd.read_csv(output_path/'testing_data.csv')

X_train_clean = X_train_clean[~X_train_clean['User_slug'].isin(df_test['User_slug'])] #removed overlap of training people which were present in testing via other contest

print(X_train_clean.shape)

# X_train_clean
# Out:
# (19074, 32)

# %% [markdown]
# saving the file

# %%
# X_train_clean.to_csv(output_path/'training_data_final.csv',index=False,quoting=csv.QUOTE_ALL) #https://chatgpt.com/s/t_69dc87e3b8b48191a31210fe483a87db
