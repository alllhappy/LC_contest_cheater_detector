# %% [markdown]
# EDA on training data only

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
df=pd.read_csv('training_data.csv')

# %%
df.columns
# Out:
# Index(['Rank', 'User_slug', 'Score', 'CurrConSolved', 'FinishTimeStamp',
#        'Q1TimeStamp', 'Q2TimeStamp', 'Q3TimeStamp', 'Q4TimeStamp', 'Q1FailCnt',
#        'Q2FailCnt', 'Q3FailCnt', 'Q4FailCnt', 'UserName', 'CountryName',
#        'RankingP', 'PostViewCnt', 'Reputation', 'TotalQsAcc', 'TotalQsSub',
#        'EasyQsAcc', 'EasyQsSub', 'MedQsAcc', 'MedQsSub', 'HardQsAcc',
#        'HardQsSub', 'ContestCnt', 'CurrRating', 'GlobalRank', 'topPercentage',
#        'ContestHistory', 'contest_id'],
#       dtype='str')

# %%
df.head()
# Out:
#    Rank         User_slug  Score  CurrConSolved      FinishTimeStamp  \
# 0  7650            ProD24     12              3  2026-03-22 03:57:15
# 1  5011      vanshika1594     12              3  2026-03-22 03:26:09
# 2  5652  yourstherapist01     12              3  2026-03-22 03:32:16
# 3  3635  Vikram_Dhatarwal     12              3  2026-03-22 03:13:26
# 4  8096        74OVxXCwcT     12              3  2026-03-22 04:04:11
#
#            Q1TimeStamp          Q2TimeStamp          Q3TimeStamp  \
# 0  2026-03-22 03:53:37  2026-03-22 03:54:58  2026-03-22 03:56:54
# 1  2026-03-22 03:07:56  2026-03-22 03:20:58  2026-03-22 03:16:40
# 2  2026-03-22 02:59:36  2026-03-22 03:12:56  2026-03-22 03:27:15
# 3  2026-03-22 02:37:05  2026-03-22 02:43:35  2026-03-22 03:13:19
# 4  2026-03-22 03:33:34  2026-03-22 03:37:29  2026-03-22 03:43:55
#
#            Q4TimeStamp  Q1FailCnt  Q2FailCnt  Q3FailCnt  Q4FailCnt  \
# 0  1970-01-01 00:00:00          0          0          0          0
# ...

# %%
#sort the increasing order of total problems

# %%
df.sort_values(by='TotalQsAcc')
df.
# Out:
#        Rank       User_slug  Score  CurrConSolved      FinishTimeStamp  \
# 10678  2552    EndlessZheng     14              3  2026-04-05 03:41:23
# 777     223           inhng     18              4  2026-03-22 03:08:25
# 1125   8994          lain12      8              2  2026-03-22 03:37:56
# 10811   868    berriescream     20              4  2026-04-05 04:11:11
# 618    7178        trdtrdsd     12              3  2026-03-22 03:50:33
# ...     ...             ...    ...            ...                  ...
# 10763  2186          REED_W     14              3  2026-04-05 03:33:21
# 11647  1829       PhoenixDD     14              3  2026-04-05 03:23:41
# 18249     1   VeritasVelata     20              4  2026-04-05 02:36:56
# 3326   1329  SupremeChicken     18              4  2026-03-22 04:08:21
# 3088    275        watercyb     18              4  2026-03-22 03:12:48
#
#                Q1TimeStamp          Q2TimeStamp          Q3TimeStamp  \
# ...

# %%
lessProblems=df[(df['TotalQsAcc']<100) & (df['Rank']<5000)].copy()

lessProblems.head()
# Out:
#     Rank      User_slug  Score  CurrConSolved      FinishTimeStamp  \
# 36  1712       Duck_You     12              3  2026-03-22 02:45:37
# 38  3612     user2784FH     12              3  2026-03-22 03:13:13
# 50  4678  Charanbandi07     12              3  2026-03-22 03:23:13
# 51  1750         s1mply     12              3  2026-03-22 02:47:15
# 54  4674  ankitverma969     12              3  2026-03-22 03:23:11
#
#             Q1TimeStamp          Q2TimeStamp          Q3TimeStamp  \
# 36  2026-03-22 02:32:14  2026-03-22 02:35:52  2026-03-22 02:45:07
# 38  2026-03-22 02:32:28  2026-03-22 02:39:19  2026-03-22 03:13:10
# 50  2026-03-22 02:34:39  2026-03-22 02:42:15  2026-03-22 03:23:11
# 51  2026-03-22 02:33:42  2026-03-22 02:38:00  2026-03-22 02:46:13
# 54  2026-03-22 02:37:25  2026-03-22 03:12:57  2026-03-22 02:54:28
#
#             Q4TimeStamp  Q1FailCnt  Q2FailCnt  Q3FailCnt  Q4FailCnt  \
# 36  1970-01-01 00:00:00          0          0          0          0
# ...

# %%
lessProblems.shape
# Out:
# (1549, 32)
