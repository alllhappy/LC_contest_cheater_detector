# %%
print('hello')
# Out:
# hello

# %%
import pandas as pd
df=pd.read_csv('contest_496/weekly_contest496.csv')
df.head()
# Out:
#    Rank      User_slug  Score  CurrConSolved  FinishTimeStamp   Q1TimeStamp  \
# 0     1  VeritasVelata     20              4       1775356616  1.775356e+09
# 1     2  ayushkumar980     20              4       1775356691  1.775356e+09
# 2     3      raunak111     20              4       1775356699  1.775356e+09
# 3     4       Mona0405     20              4       1775356752  1.775356e+09
# 4     5      scale5558     20              4       1775356771  1.775356e+09
#
#     Q2TimeStamp   Q3TimeStamp   Q4TimeStamp  Q1FailCnt  ...  EasyQsSub  \
# 0  1.775356e+09  1.775356e+09  1.775357e+09        0.0  ...       1212
# 1  1.775356e+09  1.775356e+09  1.775357e+09        0.0  ...         24
# 2  1.775356e+09  1.775356e+09  1.775357e+09        0.0  ...        198
# 3  1.775356e+09  1.775356e+09  1.775357e+09        0.0  ...         24
# 4  1.775356e+09  1.775356e+09  1.775357e+09        0.0  ...        169
#
#    MedQsAcc  MedQsSub HardQsAcc HardQsSub  ContestCnt   CurrRating  \
# ...

# %%
df.shape
# Out:
# (9408, 31)

# %%
df=pd.read_csv('contest_495/weekly_contest495.csv')
df.head()
# Out:
#    Rank       User_slug  Score  CurrConSolved  FinishTimeStamp   Q1TimeStamp  \
# 0     1  TechhnicalCode     19              4       1774751718  1.774752e+09
# 1     2   VeritasVelata     19              4       1774751783  1.774752e+09
# 2     3          mann_1     19              4       1774751822  1.774752e+09
# 3     4      w7AOsRUeuu     19              4       1774751879  1.774752e+09
# 4     5       scale5558     19              4       1774751884  1.774752e+09
#
#     Q2TimeStamp   Q3TimeStamp   Q4TimeStamp  Q1FailCnt  ...  EasyQsSub  \
# 0  1.774752e+09  1.774752e+09  1.774752e+09        0.0  ...         79
# 1  1.774752e+09  1.774752e+09  1.774752e+09        0.0  ...       1212
# 2  1.774752e+09  1.774752e+09  1.774752e+09        0.0  ...        234
# 3  1.774752e+09  1.774752e+09  1.774752e+09        0.0  ...          7
# 4  1.774752e+09  1.774752e+09  1.774752e+09        0.0  ...        169
#
#    MedQsAcc  MedQsSub HardQsAcc HardQsSub  ContestCnt   CurrRating  \
# ...

# %%
df.shape
# Out:
# (9377, 31)

# %%
df=pd.read_csv('contest_494/weekly_contest494.csv')
df.head()
# Out:
#    Rank       User_slug  Score  CurrConSolved  FinishTimeStamp   Q1TimeStamp  \
# 0     1   sunnynguyenai     18              4       1774147102  1.774147e+09
# 1     3       himank028     18              4       1774147143  1.774147e+09
# 2     4     hfgdnnvnxfg     18              4       1774147151  1.774147e+09
# 3     5  dark_knight_bt     18              4       1774147191  1.774147e+09
# 4     6   ayushkumar980     18              4       1774147203  1.774147e+09
#
#     Q2TimeStamp   Q3TimeStamp   Q4TimeStamp  Q1FailCnt  ...  EasyQsSub  \
# 0  1.774147e+09  1.774147e+09  1.774147e+09        0.0  ...         89
# 1  1.774147e+09  1.774147e+09  1.774147e+09        0.0  ...          2
# 2  1.774147e+09  1.774147e+09  1.774147e+09        0.0  ...          7
# 3  1.774147e+09  1.774147e+09  1.774147e+09        0.0  ...        345
# 4  1.774147e+09  1.774147e+09  1.774147e+09        0.0  ...         24
#
#    MedQsAcc  MedQsSub HardQsAcc HardQsSub  ContestCnt   CurrRating  \
# ...

# %%
df.shape
# Out:
# (9138, 31)
